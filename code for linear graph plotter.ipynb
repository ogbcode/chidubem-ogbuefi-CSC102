# %%
#
#code for pie chart
#grid usage
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
x_values = []
y_values=[]
x_y_no = int(input("Enter number of elements in x and y : "))
r=(x_y_no) -1
titlee=input("what will be the title of your graph:")
ylab=input("what will be the title of your y axis:")
xlab=input("what will be the title of your x axis:")
for i in range(0,x_y_no):
    ele = float(input("x value =:"))
    x_values.append(ele)
    yelement=float(input("y value=:"))
    y_values.append(yelement)
print("your x values are",x_values)
print("your y values are",y_values)
x = (x_values)
y = (y_values)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'blue','size':20}
s_x=x.sort
s_y=y.sort
slope, intercept, r, p, std_err = stats.linregress(x, y)
def myfunc(x):
    return slope * x + intercept
model = list(map(myfunc, x))
    
plt.scatter(x, y)
plt.plot(x, model)
plt.title(titlee, fontdict = font1)
plt.xlabel(xlab, fontdict = font2)
plt.ylabel(ylab, fontdict = font2)
plt.grid(color = 'green', linestyle = '--', linewidth = 1)
plt.show()
# Out:
# Enter number of elements in x and y : 5
# what will be the title of your graph:GRAPH OF SINi AGAINST SINr
# what will be the title of your y axis:sin i
# what will be the title of your x axis:sinr
# x value =:0.8860
# y value=:0.5592
# x value =:0.7716
# y value=:0.5446
# x value =:0.6659
# y value=:0.4695
# x value =:0.5
# y value=:0.3420
# x value =:0.3584
# y value=:0.2250
# your x values are [0.886, 0.7716, 0.6659, 0.5, 0.3584]
# your y values are [0.5592, 0.5446, 0.4695, 0.342, 0.225]
